# %%
import jax
import jax.numpy as jnp
from gpjax.kernels.base import AbstractKernel
import numpy as np
def dummy_npwarn_decorator_factory():
  def npwarn_decorator(x):
    return x
  return npwarn_decorator
np._no_nep50_warning = getattr(np, '_no_nep50_warning', dummy_npwarn_decorator_factory)

# Enable Float64 for more stable matrix inversions.
from jax import config
import jax.numpy as jnp
import jax.random as jr
from jaxtyping import install_import_hook
import matplotlib as mpl
import matplotlib.pyplot as plt

config.update("jax_enable_x64", True)

with install_import_hook("gpjax", "beartype.beartype"):
    import gpjax as gpx


key = jr.key(123)

cols = mpl.rcParams["axes.prop_cycle"].by_key()["color"]
def rbf(x, y, amplitude, lengthscale):
    """Plain RBF kernel between scalars x and y."""
    r = (x - y)
    return amplitude**2 * jnp.exp(-0.5 * (r / lengthscale)**2)

def drbf_dx(x, y, amplitude, lengthscale):
    """Derivative of RBF w.r.t x."""
    return (-(x - y) / lengthscale**2) * rbf(x, y, amplitude, lengthscale)

def drbf_dy(x, y, amplitude, lengthscale):
    """Derivative of RBF w.r.t y (which is just -drbf_dx w.r.t x)."""
    return ((x - y) / lengthscale**2) * rbf(x, y, amplitude, lengthscale)

def d2rbf_dxdy(x, y, amplitude, lengthscale):
    """Second partial derivative: d^2/dx dy of the RBF."""
    sq_term = ((x - y)**2 / lengthscale**4) - (1.0 / lengthscale**2)
    return amplitude**2 * sq_term * jnp.exp(-0.5 * ((x - y)/lengthscale)**2)

class DerivativeKernel(AbstractKernel):
    """
    A multi-output kernel that returns
      k00, k01, k10, k11
    for function + derivative.
    """

    def __init__(self, amplitude=1.0, lengthscale=1.0):
        super().__init__()
        self.amplitude = amplitude
        self.lengthscale = lengthscale
        
    def __call__(self, x: jnp.ndarray, y: jnp.ndarray) -> jnp.ndarray:
        """
        x, y shape: [n, 2], 
          where x[:, 0] is the location, x[:, 1] in {0,1} is the output-index (f or f').
        produce an [n, m] kernel matrix for all pairs.
        """
        # x.shape = (n, 2), y.shape = (m, 2)
        # We'll compute a (n, m) kernel matrix for each pair in x, y.
        
        # Let’s separate out the spatial locations and derivative indicators:
        x_loc = x[:, 0]
        x_out = x[:, 1].astype(int)  # 0 or 1
        y_loc = y[:, 0]
        y_out = y[:, 1].astype(int)
        
        # We'll want to build a big (n, m) matrix:
        def k_ij(i, j):
            xi = x_loc[i]
            yi = y_loc[j]
            di = x_out[i]
            dj = y_out[j]
            
            if di == 0 and dj == 0:
                # k00
                return rbf(xi, yi, self.amplitude, self.lengthscale)
            elif di == 0 and dj == 1:
                # k01 = partial wrt y
                return drbf_dy(xi, yi, self.amplitude, self.lengthscale)
            elif di == 1 and dj == 0:
                # k10 = partial wrt x
                return drbf_dx(xi, yi, self.amplitude, self.lengthscale)
            else:
                # k11 = partial^2 wrt x and y
                return d2rbf_dxdy(xi, yi, self.amplitude, self.lengthscale)

        # We can vmap over rows and columns to build up the matrix:
        n = x.shape[0]
        m = y.shape[0]
        # Build function that handles single pair (i, j):
        k_map = jax.vmap(
            lambda i: jax.vmap(lambda j: k_ij(i, j))(jnp.arange(m))
        )(jnp.arange(n))
        
        return k_map

# %%
class RegularIrrigationSim:
    def __init__(self, theta0, starts, lam, sigma_theta):
        self.soil_moist = theta0 * np.dot(np.ones_like(starts), 0 >= starts)
        self.theta0 = theta0
        self.lam = lam
        self.sigma_theta = sigma_theta
        self.time = 0.0
        self.starts = starts
        self.data = {
            'latent' : {
                't' : [0.0],
                'y' : [self.soil_moist]
            },
            'observed' : {
                't' : [],
                'y' : []
            }
        }
    
    def update(self, dt):
        self.soil_moist = self.theta0 * np.dot(np.exp(-self.lam * (self.time - self.starts)), self.time >= self.starts)
        self.time += dt
        self.data['latent']['t'].append(self.time)
        self.data['latent']['y'].append(self.soil_moist)

    def observation(self):
        self.data['observed']['t'].append(self.time)
        self.data['observed']['y'].append(self.soil_moist * np.exp(np.random.normal(0, self.sigma_theta)))


theta0 = 50
starts = np.array([0, 100, 200])
lam = 0.05
dt = 0.1
obs_interval = 3 
t = 60 * 24
sigma_theta = 0.3
min_threshold = sigma_theta
sim = RegularIrrigationSim(theta0, starts, lam, sigma_theta)
obs_timer = 0
while (sim.time < t) and (sim.soil_moist > min_threshold):
    sim.update(dt)
    obs_timer += dt
    if obs_timer >= obs_interval:
        sim.observation()
        obs_timer = 0
sim.data['observed']['t'] = sim.data['observed']['t'][:-1]
sim.data['observed']['y'] = sim.data['observed']['y'][:-1]

Xobs = jnp.array(sim.data['observed']['t']).astype(jnp.float64)
X = jnp.arange(0, max(Xobs), 1) 


def add_dims(input_array, n_dims): 
    arrays = [] 
    for col in range(n_dims):
        array = jnp.column_stack([input_array, jnp.array([col] * len(input_array))]) 
        arrays.append(array) 
    return jnp.concat(arrays, axis=0).astype(jnp.float64)

Y = jnp.array(sim.data['observed']['y']).reshape(-1, 1)
Y = jnp.concat([Y, Y], axis=0)
Xobs = add_dims(Xobs, 2)

D = gpx.Dataset(Xobs, Y)


def initialise_gp(kernel, mean, dataset):
    prior = gpx.gps.Prior(mean_function=mean, kernel=kernel)
    likelihood = gpx.likelihoods.Gaussian(
        num_datapoints=dataset.n, obs_stddev=jnp.array([1.0e-3], dtype=jnp.float64)
    )
    posterior = prior * likelihood
    return posterior

mean = gpx.mean_functions.Zero()
kernel = DerivativeKernel()

posterior = initialise_gp(kernel, mean, D) 

def optimise_mll(posterior, dataset, NIters=1000, key=key):
    # define the MLL using dataset_train
    objective = lambda p, d: -gpx.objectives.conjugate_mll(p, d)
    # Optimise to minimise the MLL
    opt_posterior, history = gpx.fit_scipy(
        model=posterior,
        objective=objective,
        train_data=dataset,
    )
    return opt_posterior

opt_post = optimise_mll(posterior, D)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[151], line 92
#      85     opt_posterior, history = gpx.fit_scipy(
#      86         model=posterior,
#      87         objective=objective,
#      88         train_data=dataset,
#      89     )
#      90     return opt_posterior
# ---> 92 opt_post = optimise_mll(posterior, D)
#
# Cell In[151], line 85, in optimise_mll(posterior, dataset, NIters, key)
#      83 objective = lambda p, d: -gpx.objectives.conjugate_mll(p, d)
#      84 # Optimise to minimise the MLL
# ---> 85 opt_posterior, history = gpx.fit_scipy(
#      86     model=posterior,
#      87     objective=objective,
#      88     train_data=dataset,
#      89 )
#      90 return opt_posterior
#
# File ~/.local/lib/python3.12/site-packages/gpjax/fit.py:234, in fit_scipy(model, objective, train_data, max_iters, verbose, safe)
#     231     scipy_grads = ravel_pytree(grads)[0]
#     232     return value, scipy_grads
# --> 234 history = [scipy_wrapper(x0)[0]]
#     235 result = minimize(
#     236     fun=scipy_wrapper,
#     237     x0=x0,
#    (...)
#     240     options={"maxiter": max_iters, "disp": verbose},
#     241 )
#     242 history = jnp.array(history)
#
#     [... skipping hidden 11 frame]
#
# File ~/.local/lib/python3.12/site-packages/gpjax/fit.py:230, in fit_scipy.<locals>.scipy_wrapper(x0)
#     228 @jax.jit
#     229 def scipy_wrapper(x0):
# --> 230     value, grads = jax.value_and_grad(loss)(scipy_to_jnp(jnp.array(x0)))
#     231     scipy_grads = ravel_pytree(grads)[0]
#     232     return value, scipy_grads
#
#     [... skipping hidden 8 frame]
#
# File ~/.local/lib/python3.12/site-packages/gpjax/fit.py:223, in fit_scipy.<locals>.loss(params)
#     221 params = transform(params, DEFAULT_BIJECTION)
#     222 model = nnx.merge(graphdef, params, *static_state)
# --> 223 return objective(model, train_data)
#
# Cell In[151], line 83, in optimise_mll.<locals>.<lambda>(p, d)
#      81 def optimise_mll(posterior, dataset, NIters=1000, key=key):
#      82     # define the MLL using dataset_train
# ---> 83     objective = lambda p, d: -gpx.objectives.conjugate_mll(p, d)
#      84     # Optimise to minimise the MLL
#      85     opt_posterior, history = gpx.fit_scipy(
#      86         model=posterior,
#      87         objective=objective,
#      88         train_data=dataset,
#      89     )
#
# File ~/.local/lib/python3.12/site-packages/gpjax/objectives.py:104, in conjugate_mll(posterior, data)
#     101 mx = posterior.prior.mean_function(x)
#     103 # Σ = (Kxx + Io²) = LLᵀ
# --> 104 Kxx = posterior.prior.kernel.gram(x)
#     105 Kxx += I_like(Kxx) * posterior.prior.jitter
#     106 Sigma = Kxx + I_like(Kxx) * obs_noise
#
# File ~/.local/lib/python3.12/site-packages/gpjax/kernels/base.py:124, in AbstractKernel.gram(self, x)
#     115 def gram(self, x: Num[Array, "N D"]) -> LinearOperator:
#     116     r"""Compute the gram matrix of the kernel.
#     117
#     118     Args:
#    (...)
#     122         The gram matrix of the kernel of shape `(N, N)`.
#     123     """
# --> 124     return self.compute_engine.gram(self, x)
#
# File ~/.local/lib/python3.12/site-packages/gpjax/kernels/computations/base.py:71, in AbstractKernelComputation.gram(self, kernel, x)
#      56 def gram(
#      57     self,
#      58     kernel: K,
#      59     x: Num[Array, "N D"],
#      60 ) -> Dense:
#      61     r"""For a given kernel, compute Gram covariance operator of the kernel function
#      62     on an input matrix of shape `(N, D)`.
#      63
#    (...)
#      69         The Gram covariance of the kernel function as a linear operator.
#      70     """
# ---> 71     Kxx = self.cross_covariance(kernel, x, x)
#      72     return PSD(Dense(Kxx))
#
# File ~/.local/lib/python3.12/site-packages/gpjax/kernels/computations/base.py:93, in AbstractKernelComputation.cross_covariance(self, kernel, x, y)
#      79 def cross_covariance(
#      80     self, kernel: K, x: Num[Array, "N D"], y: Num[Array, "M D"]
#      81 ) -> Float[Array, "N M"]:
#      82     r"""For a given kernel, compute the cross-covariance matrix on an a pair
#      83     of input matrices with shape `(N, D)` and `(M, D)`.
#      84
#    (...)
#      91         The computed cross-covariance of shape `(N, M)`.
#      92     """
# ---> 93     return self._cross_covariance(kernel, x, y)
#
# File ~/.local/lib/python3.12/site-packages/gpjax/kernels/computations/dense.py:35, in DenseKernelComputation._cross_covariance(self, kernel, x, y)
#      32 def _cross_covariance(
#      33     self, kernel: K, x: Float[Array, "N D"], y: Float[Array, "M D"]
#      34 ) -> Float[Array, "N M"]:
# ---> 35     cross_cov = vmap(lambda x: vmap(lambda y: kernel(x, y))(y))(x)
#      36     return cross_cov
#
#     [... skipping hidden 3 frame]
#
# File ~/.local/lib/python3.12/site-packages/gpjax/kernels/computations/dense.py:35, in DenseKernelComputation._cross_covariance.<locals>.<lambda>(x)
#      32 def _cross_covariance(
#      33     self, kernel: K, x: Float[Array, "N D"], y: Float[Array, "M D"]
#      34 ) -> Float[Array, "N M"]:
# ---> 35     cross_cov = vmap(lambda x: vmap(lambda y: kernel(x, y))(y))(x)
#      36     return cross_cov
#
#     [... skipping hidden 3 frame]
#
# File ~/.local/lib/python3.12/site-packages/gpjax/kernels/computations/dense.py:35, in DenseKernelComputation._cross_covariance.<locals>.<lambda>(y)
#      32 def _cross_covariance(
#      33     self, kernel: K, x: Float[Array, "N D"], y: Float[Array, "M D"]
#      34 ) -> Float[Array, "N M"]:
# ---> 35     cross_cov = vmap(lambda x: vmap(lambda y: kernel(x, y))(y))(x)
#      36     return cross_cov
#
# Cell In[47], line 68, in DerivativeKernel.__call__(self, x, y)
#      59 """
#      60 x, y shape: [n, 2],
#      61   where x[:, 0] is the location, x[:, 1] in {0,1} is the output-index (f or f').
#      62 produce an [n, m] kernel matrix for all pairs.
#      63 """
#      64 # x.shape = (n, 2), y.shape = (m, 2)
#      65 # We'll compute a (n, m) kernel matrix for each pair in x, y.
#      66
#      67 # Let’s separate out the spatial locations and derivative indicators:
# ---> 68 x_loc = x[:, 0]
#      69 x_out = x[:, 1].astype(int)  # 0 or 1
#      70 y_loc = y[:, 0]
#
# File ~/.local/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:737, in _forward_operator_to_aval.<locals>.op(self, *args)
#     736 def op(self, *args):
# --> 737   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/.local/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:350, in _getitem(self, item)
#     349 def _getitem(self, item):
# --> 350   return lax_numpy._rewriting_take(self, item)
#
# File ~/.local/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:5126, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    5123       return lax.dynamic_index_in_dim(arr, idx, keepdims=False)
#    5125 treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# -> 5126 return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    5127                unique_indices, mode, fill_value)
#
# File ~/.local/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:5135, in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#    5132 def _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    5133             unique_indices, mode, fill_value):
#    5134   idx = _merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# -> 5135   indexer = _index_to_gather(shape(arr), idx)  # shared with _scatter_update
#    5136   y = arr
#    5138   if fill_value is not None:
#
# File ~/.local/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:5243, in _index_to_gather(x_shape, idx, normalize_indices)
#    5240 def _index_to_gather(x_shape: Sequence[int], idx: Sequence[Any],
#    5241                      normalize_indices: bool = True) -> _Indexer:
#    5242   # Remove ellipses and add trailing slice(None)s.
# -> 5243   idx = _canonicalize_tuple_index(len(x_shape), idx)
#    5245   # Check for scalar boolean indexing: this requires inserting extra dimensions
#    5246   # before performing the rest of the logic.
#    5247   scalar_bool_dims: Sequence[int] = [n for n, i in enumerate(idx) if isinstance(i, bool)]
#
# File ~/.local/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:5563, in _canonicalize_tuple_index(arr_ndim, idx, array_name)
#    5561 num_dimensions_consumed = sum(not (e is None or e is Ellipsis or isinstance(e, bool)) for e in idx)
#    5562 if num_dimensions_consumed > arr_ndim:
# -> 5563   raise IndexError(
#    5564       f"Too many indices for {array_name}: {num_dimensions_consumed} "
#    5565       f"non-None/Ellipsis indices for dim {arr_ndim}.")
#    5566 ellipses = (i for i, elt in enumerate(idx) if elt is Ellipsis)
#    5567 ellipsis_index = next(ellipses, None)
#
# IndexError: Too many indices for array: 2 non-None/Ellipsis indices for dim 1.
